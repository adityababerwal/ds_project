# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("employment_trend.csv")

# %%
df.head()
# Out:
#    Year  Departments - Admn.  Departments - Acctts.   Departments - Engg  \
# 0  1964                24888                   33669              281169
# 1  1965                26403                   33476              286694
# 2  1966                34137                   31396              292932
# 3  1967                34934                   31125              288231
# 4  1968                35122                   31164              284489
#
#    Departments - S&T  Departments - Trans.   Departments - Comml.  \
# 0              41316                 190224                107111
# 1              42669                 196819                108867
# 2              43792                 191368                110408
# 3              43597                 190539                109932
# 4              44341                 187118                110304
#
#    Departments - M/Engg.  Departments - Stores  Departments - Elect.  \
# 0                 430912                 34855                 66701
# 1                 436239                 35179                 72418
# 2                 441438                 37964                 75997
# 3                 440078                 37763                 77006
# 4                 435752                 37581                 78475
#
#    Departments - Medical  Departments – R.P.S.F.
# 0                  38231                   53520
# 1                  41592                   55022
# 2                  43788                   55470
# 3                  47355                   56341
# 4                  47462                   55701

# %%
df["Total"] = df.iloc[:, 1:].sum(axis=1)

df.head()
# Out:
#    Year  Departments - Admn.  Departments - Acctts.   Departments - Engg  \
# 0  1964                24888                   33669              281169
# 1  1965                26403                   33476              286694
# 2  1966                34137                   31396              292932
# 3  1967                34934                   31125              288231
# 4  1968                35122                   31164              284489
#
#    Departments - S&T  Departments - Trans.   Departments - Comml.  \
# 0              41316                 190224                107111
# 1              42669                 196819                108867
# 2              43792                 191368                110408
# 3              43597                 190539                109932
# 4              44341                 187118                110304
#
#    Departments - M/Engg.  Departments - Stores  Departments - Elect.  \
# 0                 430912                 34855                 66701
# 1                 436239                 35179                 72418
# 2                 441438                 37964                 75997
# 3                 440078                 37763                 77006
# 4                 435752                 37581                 78475
#
#    Departments - Medical  Departments – R.P.S.F.    Total
# 0                  38231                   53520  1302596
# 1                  41592                   55022  1335378
# 2                  43788                   55470  1358690
# 3                  47355                   56341  1356901
# 4                  47462                   55701  1347509

# %%
X = df.Year.values
Y = df.Total.values

mean_X = np.mean(X)
mean_Y = np.mean(Y)

numerator = 0
denominator = 0

for i in range(len(X)):
    numerator += (X[i] - mean_X) * (Y[i] - mean_Y)
    denominator += (X[i] - mean_X) ** 2

m = numerator / denominator
c = mean_Y - (m * mean_X)

print(f"y = {m}x + {c}")
# Out:
# y = -204.09267707082864x + 1878402.648355343

# %%
plt.scatter(X, Y, label="XY Scatter")

x = np.linspace(min(X), max(X), 1000)
y = m*x + c

plt.plot(x, y, label="regression line")

plt.xlabel("Year")
plt.ylabel("Total employees")

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
