# %%
import pandas as pd

# %%
df = pd.read_excel("until-totaltime.xlsx")

# %%
df
# Out:
#       third_ac   arrival from_station_code  \
# 0            0  12:15:00               JAT
# 1            0  08:35:00               UHP
# 2            0  17:50:00               JAT
# 3            0  19:50:00               UHP
# 4            1  12:30:00              BDTS
# ...        ...       ...               ...
# 4392         0  12:25:00              KDJR
# 4393         0  03:10:00              KOTA
# 4394         0  15:20:00               ASN
# 4395         0  20:45:00                VG
# 4396         0  08:10:00               CWA
#
#                                           name  zone  chair_car  first_class  \
# 0                  Jammu Tawi Udhampur Special    NR          0            0
# 1                       UDHAMPUR JAMMUTAWI DMU    NR          0            0
# 2                             JAT UDAHMPUR DMU    NR          0            0
# 3                       UDHAMPUR JAMMUTAWI DMU    NR          0            0
# ...

# %%
df1 = df.loc[(df.from_station_code == "PNBE") | (df.to_station_code == "PNBE")]

# %%
df1.type.value_counts()
# Out:
# Exp      32
# MEMU     30
# Pass      8
# JShtb     4
# SF        4
# GR        2
# Name: type, dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
no_of_trains = [32, 30, 8, 4, 4, 2]
labels = ["Exp", "MEMU", "Pass", "JShtb", "SF", "GR"]
plt.figure(figsize=(20,13))

plt.title("Type of trains passing through PATNA JN", fontdict={'fontsize': 25})

plt.pie(no_of_trains, labels=labels, autopct='%.2f %%')

plt.show()

# %%
df_2 = df.loc[(df.type == "Raj")]

# %%
df_2.loc[df_2.distance == max(df_2.distance)]
# Out:
#      third_ac   arrival from_station_code  \
# 577         1  12:40:00               TVC
# 578         1  05:05:00               NZM
#
#                                              name zone  chair_car  \
# 577  TRIVANDRUM - DELHI H NIZAMUDDIN Rajdhani Exp   NR          0
# 578  DELHI H NIZAMUDDIN - TRIVANDRUM Rajdhani Exp   NR          0
#
#      first_class  sleeper   from_station_name number departure return_train  \
# 577            0        0  TRIVANDRUM CENTRAL  12431  19:15:00        12432
# 578            0        0  DELHI H NIZAMUDDIN  12432  11:00:00        12431
#
#     to_station_code  second_ac     to_station_name type  first_ac  distance  \
# 577             NZM          1  DELHI H NIZAMUDDIN  Raj         1      3149
# 578             TVC          1  TRIVANDRUM CENTRAL  Raj         1      3149
#
#      total time
# 577   41.416667
# 578   42.083333
