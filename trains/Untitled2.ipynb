# %%
import pandas as pd

# %%
df = pd.read_excel("trains-props.xlsx")

# %%
df.head(50)
# Out:
#     third_ac   arrival from_station_code  \
# 0          0  12:15:00               JAT
# 1          0  08:35:00               UHP
# 2          0  17:50:00               JAT
# 3          0  19:50:00               UHP
# 4          1  12:30:00              BDTS
# 5          0  00:25:00               SSA
# 6          0  06:10:00               HSR
# 7          0  23:45:00               DNA
# 8          0  04:40:00               MTD
# 9          1  17:50:00               JAT
# 10         1  21:55:00                DR
# 11         1  04:25:00              CSTM
# 12         1  03:55:00               BBS
# 13         1  06:05:00              CSTM
# 14         1  11:55:00               KOP
# 15         0  12:05:00               MMR
# 16         0  21:30:00              PUNE
# 17         1  04:55:00              CSTM
# 18         0  20:25:00              CSTM
# 19         0  20:22:00               KOP
# 20         1  06:45:00              PUNE
# 21         1  21:45:00                DR
# ...

# %%
df.loc[df.type == "Raj"]
# Out:
#       third_ac   arrival from_station_code  \
# 200          1  06:15:00              DBRT
# 201          1  05:00:00               GHY
# 202          1  05:05:00              DBRT
# 203          1  06:25:00               GHY
# 469          1  13:45:00              DBRG
# 470          1  05:45:00              NDLS
# 495          1  09:55:00               HWH
# 500          1  10:20:00              SDAH
# 501          1  10:15:00              NDLS
# 528          1  09:55:00              NDLS
# 530          1  09:55:00               HWH
# 531          1  12:40:00              NDLS
# 533          1  07:35:00              RJPB
# 534          1  06:00:00              NDLS
# 601          1  10:10:00              DBRT
# 604          1  12:40:00               TVC
# 605          1  05:05:00               NZM
# 606          1  10:20:00                SC
# 607          1  14:00:00               NZM
# 608          1  10:50:00               RNC
# 609          1  09:10:00              NDLS
# ...

# %%
df["type"].value_counts()
# Out:
# Pass     2459
# Exp      1288
# SF        719
# MEMU      297
# Hyd       121
# GR         52
# Raj        48
# Drnt       48
# SKr        42
# JShtb      40
# Shtb       31
# Mail       19
# Toy        14
# Del         8
# DEMU        4
# Klkt        3
# Name: type, dtype: int64

# %%
df.loc[df.type == "Drnt"]
# Out:
#       third_ac   arrival from_station_code  \
# 442          1  06:50:00               YPR
# 443          1  07:30:00               DEE
# 448          1  11:05:00               LTT
# 449          1  11:05:00                SC
# 450          1  11:35:00               HWH
# 451          1  17:45:00               LTT
# 452          1  18:15:00               ERS
# 455          1  11:50:00              INDB
# 461          1  13:55:00               BCT
# 462          1  12:25:00              NDLS
# 463          1  07:30:00               LKO
# 464          1  06:05:00               HWH
# 465          1  06:00:00              NDLS
# 473          0  23:15:00               CDG
# 474          0  09:30:00               ASR
# 475          0  13:30:00               MAS
# 476          0  21:50:00               CBE
# 477          1  16:00:00               HWH
# 482          1  19:40:00              CSTM
# 483          1  10:30:00               HWH
# 484          1  07:00:00               NZM
# ...

# %%
df.loc[df.type == "Hyd"]
# Out:
#       third_ac   arrival from_station_code                            name  \
# 2373         0  06:40:00               HYB      Hyderabad Lingampalli MMTS
# 2374         0  07:20:00               HYB      Hyderabad Lingampalli MMTS
# 2375         0  08:00:00               HYB      Hyderabad Lingampalli MMTS
# 2376         0  08:30:00               HYB      Hyderabad Lingampalli MMTS
# 2377         0  09:00:00               HYB      Hyderabad Lingampalli MMTS
# ...        ...       ...               ...                             ...
# 4838         0  14:05:00                FM      Falaknuma Lingampalli MMTS
# 5079         0  21:30:00               HYB      Hyderabad Lingampalli MMTS
# 5084         0  20:25:00                FM  Falaknuma Lingampalli Suburban
# 5097         0  16:20:00               HYB      Hyderabad Lingampalli MMTS
# 5098         0  20:55:00                FM      Falaknuma Lingampalli MMTS
#
# ...

# %%
df.loc[(df.type == "Hyd") & (df.name == "Hyderabad.*")]
# Out:
# Empty DataFrame
# Columns: [third_ac, arrival, from_station_code, name, zone, chair_car, first_class, duration_m, sleeper, from_station_name, number, departure, return_train, to_station_code, second_ac, to_station_name, duration_h, type, first_ac, distance]
# Index: []
