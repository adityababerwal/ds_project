# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("expenses-trend.csv")

# %%
df
# Out:
#     Year  Administration - D.No.4  Repairs and Maintenance - D.No.5  \
# 0   1964                    49.28                            139.38
# 1   1965                    55.60                            157.58
# 2   1966                    60.46                            169.95
# 3   1967                    66.41                            190.14
# 4   1968                    71.11                            209.05
# 5   1969                    75.16                            223.77
# 6   1970                    83.05                            248.53
# 7   1971                    87.64                            272.74
# 8   1972                    91.97                            309.89
# 9   1973                   102.30                            356.28
# 10  1974                   129.13                            452.74
# 11  1975                   155.89                            557.62
# 12  1976                   152.84                            595.61
# 13  1977                   153.95                            608.70
# 14  1978                   162.03                            653.65
#
#     Operation Staff - D.No.6  Operation Fuel - D.No.7  \
# 0                      89.47                    92.07
# 1                     102.54                   101.05
# 2                     112.00                   110.17
# 3                     123.85                   127.82
# 4                     133.60                   139.12
# 5                     141.38                   151.17
# 6                     157.39                   146.93
# 7                     175.75                   155.92
# 8                     183.48                   162.37
# 9                     205.30                   158.85
# 10                    264.91                   197.02
# 11                    312.33                   254.52
# 12                    312.54                   288.31
# 13                    316.25                   299.17
# 14                    355.00                   307.16
#
#     Operation Other than Staff and Fuel - D.No.8  Misc. Expenses - D.No.9  \
# 0                                          23.73                    24.87
# 1                                          25.61                    26.35
# 2                                          26.37                    28.26
# 3                                          30.97                    28.23
# 4                                          34.33                    29.28
# 5                                          36.54                    33.09
# 6                                          37.99                    33.99
# 7                                          41.95                    36.74
# 8                                          44.70                    36.23
# 9                                          46.70                    37.21
# 10                                         61.13                    50.01
# 11                                         84.58                    54.36
# 12                                         87.57                    58.13
# 13                                         87.95                    58.03
# 14                                         84.68                    57.80
#
#     Labour Welfare - D.No.10  Total - D.Nos.4 to 10  \
# 0                      16.19                 434.99
# 1                      18.62                 487.35
# 2                      20.12                 527.33
# 3                      22.03                 589.45
# 4                      22.67                 639.16
# 5                      23.76                 684.87
# 6                      26.29                 734.17
# 7                      28.45                 799.19
# 8                      30.22                 858.86
# 9                      33.74                 940.38
# 10                     43.40                1198.34
# 11                     52.60                1471.90
# 12                     53.75                1548.75
# 13                     55.13                1579.18
# 14                     57.75                1678.07
#
#     Appropriation to Depreciation Reserve Fund  \
# 0                                         83.0
# 1                                         85.0
# 2                                        100.0
# 3                                         95.0
# 4                                         95.0
# 5                                         95.0
# 6                                        100.0
# 7                                        105.0
# 8                                        110.0
# 9                                        115.0
# 10                                       115.0
# 11                                       115.0
# 12                                       135.0
# 13                                       140.0
# 14                                       145.0
#
#     Appropriation to Railway Pension Fund  \
# 0                                   11.50
# 1                                   12.00
# 2                                   13.50
# 3                                    9.93
# 4                                    9.90
# 5                                    9.90
# 6                                   14.85
# 7                                   11.38
# 8                                   15.85
# 9                                   15.85
# 10                                  15.85
# 11                                  24.25
# 12                                  34.40
# 13                                  39.35
# 14                                  49.20
#
#     Total Working Exp. Incl. App. to DRF and PF  Suspense  \
# 0                                        529.49     -1.54
# 1                                        584.35     -1.51
# 2                                        640.83     -1.72
# 3                                        694.38     -1.23
# 4                                        744.06     -2.38
# 5                                        789.77     -0.07
# 6                                        849.02     -1.83
# 7                                        915.57     -3.87
# 8                                        984.71     -2.23
# 9                                       1071.23     -5.05
# 10                                      1329.19    -12.06
# 11                                      1611.15     -1.74
# 12                                      1718.15      0.20
# 13                                      1758.53     -8.60
# 14                                      1872.27     -4.90
#
#     Payment to Worked Lines  Total Working Expenses
# 0                      0.16                  528.11
# 1                      0.19                  583.03
# 2                      0.14                  639.25
# 3                      0.15                  693.30
# 4                      0.25                  741.93
# 5                      0.18                  789.88
# 6                      0.15                  847.34
# 7                      0.15                  911.85
# 8                      0.14                  982.62
# 9                      0.15                 1066.33
# 10                     0.16                 1317.29
# 11                     0.20                 1609.61
# 12                     0.21                 1718.56
# 13                     0.19                 1750.12
# 14                     0.18                 1867.55

# %%
X = df.Year.values
Y = df["Total Working Expenses"].values

mean_X = np.mean(X)
mean_Y = np.mean(Y)

numerator = 0
denominator = 0

for i in range(len(X)):
    numerator += (X[i] - mean_X) * (Y[i] - mean_Y)
    denominator += (X[i] - mean_X) ** 2
    
m = numerator / denominator
c = mean_Y - (m*mean_X)

print(f"y = {m}x + {c}")
# Out:
# y = 99.48096428571426x + -195007.19594047614

# %%
x = np.linspace(min(X), max(X))
y = m*x + c

plt.plot(x, y, label="regression line")
plt.scatter(X, Y, label="XY Scatter")

plt.xlabel("Year")
plt.ylabel("Total Expense")

plt.show()

# %% [markdown]
# # Finding R sq value

# %%
# to find R2 value

# sum of square of residuals
ss_r = 0

# total sum of squares
ss_t = 0

for i in range(len(X)):
    y_pred = m*X[i] + c
    ss_r += (Y[i] - y_pred) ** 2
    ss_t += (Y[i] - mean_Y) ** 2

r2 = 1 - (ss_r / ss_t )
print(r2)
# Out:
# 0.924231229394755
