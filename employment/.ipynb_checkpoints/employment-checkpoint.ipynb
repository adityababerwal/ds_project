# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("employment-trend.csv")

# %%
df.head()
# Out:
#    Year  Railway Zones/Units/Board and Other Offices - Central  \
# 0  2000                                             213199
# 1  2001                                             208024
# 2  2002                                             204707
# 3  2003                                             126813
# 4  2004                                             124757
#
#    Railway Zones/Units/Board and Other Offices - Eastern  \
# 0                                             208237
# 1                                             204376
# 2                                             195932
# 3                                             133613
# 4                                             131513
#
#    Railway Zones/Units/Board and Other Offices - East Central  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                            92165.0
# 4                                            84180.0
#
#    Railway Zones/Units/Board and Other Offices - East Cost  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                            43985.0
# 4                                            44450.0
#
#    Railway Zones/Units/Board and Other Offices - Metro Railway Kolkata  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Railway Zones/Units/Board and Other Offices - Northern  \
# 0                                             242747
# 1                                             236973
# 2                                             231923
# 3                                             164304
# 4                                             161906
#
#    Railway Zones/Units/Board and Other Offices - North Central  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                            72592.0
# 4                                            79039.0
#
#    Railway Zones/Units/Board and Other Offices - North Eastern  \
# 0                                              97570
# 1                                              95233
# 2                                              91957
# 3                                              64158
# 4                                              63769
#
#    Railway Zones/Units/Board and Other Offices - Northeast Frontier  ...  \
# 0                                              79390                 ...
# 1                                              76508                 ...
# 2                                              75159                 ...
# 3                                              74085                 ...
# 4                                              72685                 ...
#
#    Railway Zones/Units/Board and Other Offices - Southern  \
# 0                                             133587
# 1                                             130579
# 2                                             126992
# 3                                             106844
# 4                                             106258
#
#    Railway Zones/Units/Board and Other Offices - South Central  \
# 0                                             121820
# 1                                             119410
# 2                                             116627
# 3                                              95919
# 4                                              95009
#
#    Railway Zones/Units/Board and Other Offices - South Eastern  \
# 0                                             197525
# 1                                             195725
# 2                                             194055
# 3                                              98390
# 4                                              95830
#
#    Railway Zones/Units/Board and Other Offices - Southeast Central  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                            40336.0
# 4                                            42722.0
#
#    Railway Zones/Units/Board and Other Offices - South Western  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                            33373.0
# 4                                            33654.0
#
#    Railway Zones/Units/Board and Other Offices - Western  \
# 0                                             182916
# 1                                             178210
# 2                                             171971
# 3                                             112842
# 4                                             110447
#
#    Railway Zones/Units/Board and Other Offices - West Central  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                            61178.0
# 4                                            60401.0
#
#    Railway Zones/Units/Board and Other Offices - Production Units  \
# 0                                              51241
# 1                                              49885
# 2                                              48074
# 3                                              46521
# 4                                              45596
#
#    Railway Zones/Units/Board and Other Offices - Railway Board & Metropolitan Transport Projects  \
# 0                                              21153
# 1                                              19893
# 2                                              18487
# 3                                              18620
# 4                                              14504
#
#    Grand total
# 0      1549385
# 1      1514816
# 2      1475884
# 3      1445428
# 4      1424389
#
# [5 rows x 21 columns]

# %%
X = df.Year.values
Y = df["Grand total"].values

mean_X = np.mean(X)
mean_Y = np.mean(Y)

numerator = 0
denominator = 0

for i in range(len(X)):
    numerator += (X[i] - mean_X) * (Y[i] - mean_Y)
    denominator += (X[i] - mean_X) ** 2

m = numerator / denominator
c = mean_Y - (m * mean_X)

print(f"y = {m}x + {c}")
# Out:
# y = -19892.21978021978x + 41305240.87912088

# %%
plt.scatter(X, Y, label="XY Scatter")

x = np.linspace(min(X), max(X), 1000)
y = m*x + c

plt.plot(x, y, label="Regression line", c='r')

plt.xlabel("Year")
plt.ylabel("Total employees")
plt.legend()

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# sum of square of residuals
ss_r = 0

# total sum of squares
ss_t = 0

for i in range(len(X)):
    y_pred = m*X[i] + c
    ss_r += (Y[i] - y_pred) ** 2
    ss_t += (Y[i] - mean_Y) ** 2

r2 = 1 - (ss_r / ss_t )
print(r2)
# Out:
# 0.9460847939482755
